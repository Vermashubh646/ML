# %%
import pandas as pd

# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1/likes"

querystring = {"code_or_id_or_url":"CxYQJO8xuC6"}

headers = {
	"x-rapidapi-key": "00a8811905mshf768804e1718203p1ea997jsna1fcd61247b0",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'count': 856, 'items': [{'full_name': 'Smith George', 'id': '67494313427', 'is_new': False, 'is_private': False, 'is_verified': False, 'latest_reel_media': 0, 'profile_pic_id': '3390997884742372166', 'profile_pic_url': 'https://scontent-lax3-1.cdninstagram.com/v/t51.2885-19/448268534_822749782763836_7690555371956293917_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-lax3-1.cdninstagram.com&_nc_cat=104&_nc_ohc=PWL8_FeGrdkQ7kNvgHO1DH4&edm=AHUBisUBAAAA&ccb=7-5&oh=00_AYCsmWRC-ZYB4kAYEe8bUKdcm9D4SlJHDvpNTJHvb6GQkw&oe=6675C8FC&_nc_sid=bc52df', 'username': 'smithgeorge5456'}, {'full_name': '.', 'id': '57286160189', 'is_new': False, 'is_private': True, 'is_verified': False, 'latest_reel_media': 0, 'profile_pic_url': 'https://instagram.flos5-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.flos5-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=ZgTXJLK5wfkQ7kNvgGSnrHM&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AYD
# ...

# %%
df= pd.DataFrame(response.json()['data']['items'])[['id','full_name','username','is_new','is_private','is_verified']]

# %%
df
# Out:
#               id             full_name                 username  is_new  \
# 0    67494313427          Smith George          smithgeorge5456   False
# 1    57286160189                     .              day___castr   False
# 2    53452420940       ___&oumodip--->              soumodipxyz   False
# 3    54638460843       Mohamed Mohamed              mohamed_eam   False
# 4    66536363216              @martinz                 mar73892   False
# ..           ...                   ...                      ...     ...
# 851  20003393446                  اللة               rahil88000   False
# 852  63950243159                    🤍.                sll.xx.o8   False
# 853  49806343969  रिज़वान खान गाजीपुरी   rizwankhan_ghazipuri61   False
# 854  49858828071        Rïdèr Himåñshū  classic___advance__7013   False
# 855  59389528404                    メグ            nana.maru0830   False
#
#      is_private  is_verified
# 0         False        False
# 1          True        False
# ...

# %%
(df).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           856 non-null    object
#  1   full_name    856 non-null    object
#  2   username     856 non-null    object
#  3   is_new       856 non-null    bool
#  4   is_private   856 non-null    bool
#  5   is_verified  856 non-null    bool
# dtypes: bool(3), object(3)
# memory usage: 22.7+ KB

# %%
df.to_csv('insta_RapidAPI.csv')
